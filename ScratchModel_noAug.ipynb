# %% [markdown]
# # Import Packages

# %%
import pandas as pd
import numpy as np
import os as os 
import random 
import sys 
import datetime as dt 
import tensorflow as tf
from tensorflow import keras 
from sklearn.model_selection import train_test_split
from sklearn.metrics import PrecisionRecallDisplay
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score
from itertools import cycle
from keras import backend as K 
import zipfile
! pip install xlrd # need to read in the xlsx sheet later
! pip install image-classifiers
from classification_models.keras import Classifiers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
# !pip install tqdm
from tqdm.notebook import tqdm
# Out:
# Requirement already satisfied: xlrd in /usr/local/lib/python3.7/dist-packages (1.1.0)
# Requirement already satisfied: image-classifiers in /usr/local/lib/python3.7/dist-packages (1.0.0)
# Requirement already satisfied: keras-applications<=1.0.8,>=1.0.7 in /usr/local/lib/python3.7/dist-packages (from image-classifiers) (1.0.8)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.7/dist-packages (from keras-applications<=1.0.8,>=1.0.7->image-classifiers) (1.21.6)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras-applications<=1.0.8,>=1.0.7->image-classifiers) (3.1.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->keras-applications<=1.0.8,>=1.0.7->image-classifiers) (1.5.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (4.64.0)

# %% [markdown]
# # Set Seeds

# %%
tf.random.set_seed(261)
random.seed(1126)
np.random.seed(1030)

# %% [markdown]
# # Mount Drive
#
# Load in the CheXpert data as the ZIP downloaded from their website. Unzip using code below. Need to run again if runtime is disconnected.
#
# Also need to upload the CHEXPERT DEMO Excel file. The original dataset does not contain the `race` labels. The DEMO file is what maps the pictures to the `race` labels.

# %% [markdown]
# The data will come in on the left as so:
#
# ![Screen Shot 2022-05-03 at 3.14.49 PM.png](data:image/png;base64,...)

# %%
# Mount the drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# QJ's base directory:
base_dir = 'drive/My Drive/Colab Notebooks/Computer Vision Project/'

# CheXpert directory after unzipping
chexpert_dir = "CheXpert-v1.0-small/"
chexper_train_dir = "CheXpert-v1.0-small/train/"
chexper_test_dir = "CheXpert-v1.0-small/valid/"
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Unzip Dataset

# %%
# takes 2 min to run
zip_ref = zipfile.ZipFile(base_dir + 'CheXpert-v1.0-small.zip', 'r')
zip_ref.extractall()
zip_ref.close()

# %% [markdown]
# # Bring in Main Label Files

# %%
train_labels = pd.read_csv(chexpert_dir + 'train.csv')
test_labels = pd.read_csv(chexpert_dir + 'valid.csv')

# %% [markdown]
# # Bring in Race Labels

# %%
# rename the PATIENT column as ID for joining later
race_labels = pd.read_excel(base_dir + 'CHEXPERT DEMO.xlsx').rename(columns = {'PATIENT' : 'ID'})

# %%
race_labels.head(5)
# Out:
#              ID  GENDER  AGE_AT_CXR PRIMARY_RACE                ETHNICITY
# 0  patient24428    Male          61        White  Non-Hispanic/Non-Latino
# 1  patient48289  Female          39        Other          Hispanic/Latino
# 2  patient33856  Female          81        White  Non-Hispanic/Non-Latino
# 3  patient41673  Female          42      Unknown                  Unknown
# 4  patient48493    Male          71        White  Non-Hispanic/Non-Latino

# %% [markdown]
# # Code Race Labels
#
# For race, we decided to run a model predicting the following for racial categories: Asian, Black, White, and Native American .
#
# The original CheXpert data has more race categories. However, the amount of training data for certain groups was so low, we did not think it would yield strong results. Hispanic was folded into other racial groups as "Racial Group" + (non)Hispanic. For simplicity, we ignored the non-Hispanic/Hispanic labeling and combined American Indian with Native American. Due to low number of observations, we took out Pacific Islander and photos where race is unknown.

# %% [markdown]
# ### Merge Race Labels with Original Label data (Train)

# %%
train_labels.head(5)
# Out:
#                                                 Path     Sex  Age  \
# 0  CheXpert-v1.0-small/train/patient00001/study1/...  Female   68
# 1  CheXpert-v1.0-small/train/patient00002/study2/...  Female   87
# 2  CheXpert-v1.0-small/train/patient00002/study1/...  Female   83
# 3  CheXpert-v1.0-small/train/patient00002/study1/...  Female   83
# 4  CheXpert-v1.0-small/train/patient00003/study1/...    Male   41
#
#   Frontal/Lateral AP/PA  No Finding  Enlarged Cardiomediastinum  Cardiomegaly  \
# 0         Frontal    AP         1.0                         NaN           NaN
# 1         Frontal    AP         NaN                         NaN          -1.0
# 2         Frontal    AP         NaN                         NaN           NaN
# 3         Lateral   NaN         NaN                         NaN           NaN
# 4         Frontal    AP         NaN                         NaN           NaN
#
#    Lung Opacity  Lung Lesion  Edema  Consolidation  Pneumonia  Atelectasis  \
# 0           NaN          NaN    NaN            NaN        NaN          NaN
# 1           1.0          NaN   -1.0           -1.0        NaN         -1.0
# 2           1.0          NaN    NaN           -1.0        NaN          NaN
# 3           1.0          NaN    NaN           -1.0        NaN          NaN
# 4           NaN          NaN    1.0            NaN        NaN          NaN
#
#    Pneumothorax  Pleural Effusion  Pleural Other  Fracture  Support Devices
# 0           0.0               NaN            NaN       NaN              1.0
# 1           NaN              -1.0            NaN       1.0              NaN
# 2           NaN               NaN            NaN       1.0              NaN
# 3           NaN               NaN            NaN       1.0              NaN
# 4           0.0               NaN            NaN       NaN              NaN

# %%
race_labels.PRIMARY_RACE.unique()
# Out:
# array(['White', 'Other', 'Unknown', 'White, non-Hispanic', 'Asian', nan,
#        'Black or African American', 'Black, non-Hispanic',
#        'Other, Hispanic', 'Race and Ethnicity Unknown',
#        'Asian, non-Hispanic', 'Pacific Islander, non-Hispanic',
#        'Native Hawaiian or Other Pacific Islander', 'Other, non-Hispanic',
#        'Patient Refused', 'White, Hispanic', 'Black, Hispanic',
#        'Asian, Hispanic', 'American Indian or Alaska Native',
#        'Native American, Hispanic', 'Native American, non-Hispanic',
#        'Pacific Islander, Hispanic', 'Asian - Historical Conv',
#        'White or Caucasian'], dtype=object)

# %%
# extract the patient id number from the Path variable (index 2 in the path)
path_split_train =  train_labels.Path.str.split("/", expand = True)
train_labels['ID'] = path_split_train[2]

# merge the race labels with the main label dataset
train_labels = train_labels.merge(race_labels, on = 'ID')

# %%
train_labels.head(5)
# Out:
#                                                 Path     Sex  Age  \
# 0  CheXpert-v1.0-small/train/patient00001/study1/...  Female   68
# 1  CheXpert-v1.0-small/train/patient00002/study2/...  Female   87
# 2  CheXpert-v1.0-small/train/patient00002/study1/...  Female   83
# 3  CheXpert-v1.0-small/train/patient00002/study1/...  Female   83
# 4  CheXpert-v1.0-small/train/patient00003/study1/...    Male   41
#
#   Frontal/Lateral AP/PA  No Finding  Enlarged Cardiomediastinum  Cardiomegaly  \
# 0         Frontal    AP         1.0                         NaN           NaN
# 1         Frontal    AP         NaN                         NaN          -1.0
# 2         Frontal    AP         NaN                         NaN           NaN
# 3         Lateral   NaN         NaN                         NaN           NaN
# 4         Frontal    AP         NaN                         NaN           NaN
#
#    Lung Opacity  Lung Lesion  ...  Pneumothorax  Pleural Effusion  \
# 0           NaN          NaN  ...           0.0               NaN
# 1           1.0          NaN  ...           NaN              -1.0
# 2           1.0          NaN  ...           NaN               NaN
# 3           1.0          NaN  ...           NaN               NaN
# 4           NaN          NaN  ...           0.0               NaN
#
#    Pleural Other  Fracture  Support Devices            ID  GENDER  AGE_AT_CXR  \
# 0            NaN       NaN              1.0  patient00001  Female          68
# 1            NaN       1.0              NaN  patient00002  Female          87
# 2            NaN       1.0              NaN  patient00002  Female          87
# 3            NaN       1.0              NaN  patient00002  Female          87
# 4            NaN       NaN              NaN  patient00003    Male          41
#
#           PRIMARY_RACE                ETHNICITY
# 0                Other  Non-Hispanic/Non-Latino
# 1  White, non-Hispanic  Non-Hispanic/Non-Latino
# 2  White, non-Hispanic  Non-Hispanic/Non-Latino
# 3  White, non-Hispanic  Non-Hispanic/Non-Latino
# 4  White, non-Hispanic  Non-Hispanic/Non-Latino
#
# [5 rows x 24 columns]

# %% [markdown]
# ### Adjust Race Labels
#
# Again, we are compressing our race labels into 4 categories: Asian, Black/African American, White, and Native American

# %%
# need na = False bc we want missing values to be coerced to False instead of nan

black_african_american_index = (train_labels.PRIMARY_RACE.str.contains('Black', na = False))
train_labels.loc[black_african_american_index, 'Race'] = 'Black/African American'

white_index = (train_labels.PRIMARY_RACE.str.contains('White', na = False))
train_labels.loc[white_index, 'Race'] = 'White'

asian_index = (train_labels.PRIMARY_RACE.str.contains('Asian', na = False))
train_labels.loc[asian_index, 'Race'] = 'Asian'

native_american_index = (train_labels.PRIMARY_RACE.str.contains('Native|Indian', na = False, regex = True))
train_labels.loc[native_american_index, 'Race'] = 'Native American'

# %%
train_labels.head(20)
# Out:
#                                                  Path     Sex  Age  \
# 0   CheXpert-v1.0-small/train/patient00001/study1/...  Female   68
# 1   CheXpert-v1.0-small/train/patient00002/study2/...  Female   87
# 2   CheXpert-v1.0-small/train/patient00002/study1/...  Female   83
# 3   CheXpert-v1.0-small/train/patient00002/study1/...  Female   83
# 4   CheXpert-v1.0-small/train/patient00003/study1/...    Male   41
# 5   CheXpert-v1.0-small/train/patient00004/study1/...  Female   20
# 6   CheXpert-v1.0-small/train/patient00004/study1/...  Female   20
# 7   CheXpert-v1.0-small/train/patient00005/study1/...    Male   33
# 8   CheXpert-v1.0-small/train/patient00005/study1/...    Male   33
# 9   CheXpert-v1.0-small/train/patient00005/study2/...    Male   33
# 10  CheXpert-v1.0-small/train/patient00005/study2/...    Male   33
# 11  CheXpert-v1.0-small/train/patient00006/study1/...  Female   42
# 12  CheXpert-v1.0-small/train/patient00007/study1/...    Male   69
# 13  CheXpert-v1.0-small/train/patient00007/study2/...    Male   69
# 14  CheXpert-v1.0-small/train/patient00008/study1/...    Male   81
# 15  CheXpert-v1.0-small/train/patient00008/study2/...    Male   81
# 16  CheXpert-v1.0-small/train/patient00009/study1/...    Male   76
# 17  CheXpert-v1.0-small/train/patient00009/study1/...    Male   76
# 18  CheXpert-v1.0-small/train/patient00010/study1/...  Female   50
# 19  CheXpert-v1.0-small/train/patient00010/study1/...  Female   50
#
#    Frontal/Lateral AP/PA  No Finding  Enlarged Cardiomediastinum  \
# 0          Frontal    AP         1.0                         NaN
# 1          Frontal    AP         NaN                         NaN
# 2          Frontal    AP         NaN                         NaN
# 3          Lateral   NaN         NaN                         NaN
# 4          Frontal    AP         NaN                         NaN
# 5          Frontal    PA         1.0                         0.0
# 6          Lateral   NaN         1.0                         0.0
# 7          Frontal    PA         1.0                         NaN
# 8          Lateral   NaN         1.0                         NaN
# 9          Frontal    AP         NaN                         NaN
# 10         Frontal    AP         NaN                         NaN
# 11         Frontal    AP         1.0                         0.0
# 12         Frontal    AP         NaN                         NaN
# 13         Frontal    AP         NaN                         1.0
# 14         Frontal    AP         NaN                         NaN
# 15         Frontal    AP         NaN                         NaN
# 16         Frontal    PA         NaN                         NaN
# 17         Lateral   NaN         NaN                         NaN
# 18         Frontal    PA         1.0                         0.0
# 19         Lateral   NaN         1.0                         0.0
#
#     Cardiomegaly  Lung Opacity  Lung Lesion  ...  Pleural Effusion  \
# 0            NaN           NaN          NaN  ...               NaN
# 1           -1.0           1.0          NaN  ...              -1.0
# 2            NaN           1.0          NaN  ...               NaN
# 3            NaN           1.0          NaN  ...               NaN
# 4            NaN           NaN          NaN  ...               NaN
# 5            NaN           NaN          NaN  ...               0.0
# 6            NaN           NaN          NaN  ...               0.0
# 7            0.0           NaN          NaN  ...               0.0
# 8            0.0           NaN          NaN  ...               0.0
# 9            NaN           NaN          NaN  ...               NaN
# 10           NaN           NaN          NaN  ...               NaN
# 11           NaN           NaN          NaN  ...               0.0
# 12           1.0           1.0          NaN  ...               0.0
# 13           NaN           1.0          NaN  ...               0.0
# 14           NaN           1.0          NaN  ...               1.0
# 15           NaN           1.0          NaN  ...               1.0
# 16           1.0           NaN          NaN  ...               NaN
# 17           1.0           NaN          NaN  ...               NaN
# 18           NaN           0.0          NaN  ...               0.0
# 19           NaN           0.0          NaN  ...               0.0
#
#     Pleural Other  Fracture  Support Devices            ID  GENDER  \
# 0             NaN       NaN              1.0  patient00001  Female
# 1             NaN       1.0              NaN  patient00002  Female
# 2             NaN       1.0              NaN  patient00002  Female
# 3             NaN       1.0              NaN  patient00002  Female
# 4             NaN       NaN              NaN  patient00003    Male
# 5             NaN       NaN              NaN  patient00004  Female
# 6             NaN       NaN              NaN  patient00004  Female
# 7             NaN       NaN              1.0  patient00005    Male
# 8             NaN       NaN              1.0  patient00005    Male
# 9             NaN       NaN              NaN  patient00005    Male
# 10            NaN       NaN              NaN  patient00005    Male
# 11            NaN       NaN              NaN  patient00006  Female
# 12            NaN       0.0              1.0  patient00007    Male
# 13            NaN       0.0              1.0  patient00007    Male
# 14            NaN       NaN              1.0  patient00008    Male
# 15            NaN       NaN              1.0  patient00008    Male
# 16            NaN       NaN              NaN  patient00009    Male
# 17            NaN       NaN              NaN  patient00009    Male
# 18            NaN       NaN              NaN  patient00010  Female
# 19            NaN       NaN              NaN  patient00010  Female
#
#     AGE_AT_CXR                               PRIMARY_RACE  \
# 0           68                                      Other
# 1           87                        White, non-Hispanic
# 2           87                        White, non-Hispanic
# 3           87                        White, non-Hispanic
# 4           41                        White, non-Hispanic
# 5           20                  Black or African American
# 6           20                  Black or African American
# 7           33                                      White
# 8           33                                      White
# 9           33                                      White
# 10          33                                      White
# 11          42  Native Hawaiian or Other Pacific Islander
# 12          69                                      Other
# 13          69                                      Other
# 14          81                                      White
# 15          81                                      White
# 16          76                                      Asian
# 17          76                                      Asian
# 18          50                                      Other
# 19          50                                      Other
#
#                   ETHNICITY                    Race
# 0   Non-Hispanic/Non-Latino                     NaN
# 1   Non-Hispanic/Non-Latino                   White
# 2   Non-Hispanic/Non-Latino                   White
# 3   Non-Hispanic/Non-Latino                   White
# 4   Non-Hispanic/Non-Latino                   White
# 5   Non-Hispanic/Non-Latino  Black/African American
# 6   Non-Hispanic/Non-Latino  Black/African American
# 7   Non-Hispanic/Non-Latino                   White
# 8   Non-Hispanic/Non-Latino                   White
# 9   Non-Hispanic/Non-Latino                   White
# 10  Non-Hispanic/Non-Latino                   White
# 11  Non-Hispanic/Non-Latino         Native American
# 12          Hispanic/Latino                     NaN
# 13          Hispanic/Latino                     NaN
# 14  Non-Hispanic/Non-Latino                   White
# 15  Non-Hispanic/Non-Latino                   White
# 16  Non-Hispanic/Non-Latino                   Asian
# 17  Non-Hispanic/Non-Latino                   Asian
# 18          Hispanic/Latino                     NaN
# 19          Hispanic/Latino                     NaN
#
# [20 rows x 25 columns]

# %%
train_labels.Race.value_counts(dropna = False)
# Out:
# White                     125491
# NaN                        58491
# Asian                      23272
# Black/African American     11961
# Native American             3346
# Name: Race, dtype: int64

# %%
sum(train_labels.Race.value_counts(dropna = False))
# Out:
# 222561

# %% [markdown]
# # Split into Train, Val, Test
#
# This dataset was originally released for a competition. Thus the files are split into `Train` and `Validation`. The `Train` set has 222561 observations while the `Validation` set only has 232 (both numbers are before taking out NAs).
#
# For the sake of practicality, we are going to split our `train` data into train, test, and val.
#
#
# *   test = 10%
# *   val = 27%
# *   train = 63%

# %%
train_labels = train_labels.dropna(subset=['Race'])

train, test = train_test_split(train_labels, test_size = 0.10, random_state = 261, stratify = train_labels[['Race']])

train, val = train_test_split(train, test_size = 0.30, random_state = 261, stratify = train[['Race']])

# %%
print(len(train))
print(len(val))
print(len(test))
# Out:
# 103364
# 44299
# 16407

# %% [markdown]
# # Transfer Learning: Building a model from Scratch

# %% [markdown]
# ### Define input size
#
# Images are between about 320-370 by 320-370

# %%
target_height = 150
target_width = 150
size = (target_height, target_width)
size_3d = (target_height, target_width, 3)
number_classes = 4

# %% [markdown]
# ### Get Model Base

# %%
ResNet34, preprocess_input = Classifiers.get('resnet34')
model = ResNet34(input_shape = size_3d, weights=None, include_top = False) # random weights used

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  data (InputLayer)              [(None, 150, 150, 3  0           []
#                                 )]
#
#  bn_data (BatchNormalization)   (None, 150, 150, 3)  9           ['data[0][0]']
#
#  zero_padding2d (ZeroPadding2D)  (None, 156, 156, 3)  0          ['bn_data[0][0]']
#
#  conv0 (Conv2D)                 (None, 75, 75, 64)   9408        ['zero_padding2d[0][0]']
#
#  bn0 (BatchNormalization)       (None, 75, 75, 64)   256         ['conv0[0][0]']
#
#  relu0 (Activation)             (None, 75, 75, 64)   0           ['bn0[0][0]']
#
#  zero_padding2d_1 (ZeroPadding2  (None, 77, 77, 64)  0           ['relu0[0][0]']
#  D)
#
#  pooling0 (MaxPooling2D)        (None, 38, 38, 64)   0           ['zero_padding2d_1[0][0]']
#
#  stage1_unit1_bn1 (BatchNormali  (None, 38, 38, 64)  256         ['pooling0[0][0]']
#  zation)
#
#  stage1_unit1_relu1 (Activation  (None, 38, 38, 64)  0           ['stage1_unit1_bn1[0][0]']
#  )
#
#  zero_padding2d_2 (ZeroPadding2  (None, 40, 40, 64)  0           ['stage1_unit1_relu1[0][0]']
#  D)
#
#  stage1_unit1_conv1 (Conv2D)    (None, 38, 38, 64)   36864       ['zero_padding2d_2[0][0]']
#
#  stage1_unit1_bn2 (BatchNormali  (None, 38, 38, 64)  256         ['stage1_unit1_conv1[0][0]']
#  zation)
#
#  stage1_unit1_relu2 (Activation  (None, 38, 38, 64)  0           ['stage1_unit1_bn2[0][0]']
#  )
#
#  zero_padding2d_3 (ZeroPadding2  (None, 40, 40, 64)  0           ['stage1_unit1_relu2[0][0]']
#  D)
#
#  stage1_unit1_conv2 (Conv2D)    (None, 38, 38, 64)   36864       ['zero_padding2d_3[0][0]']
#
#  stage1_unit1_sc (Conv2D)       (None, 38, 38, 64)   4096        ['stage1_unit1_relu1[0][0]']
#
#  add (Add)                      (None, 38, 38, 64)   0           ['stage1_unit1_conv2[0][0]',
#                                                                   'stage1_unit1_sc[0][0]']
#
#  stage1_unit2_bn1 (BatchNormali  (None, 38, 38, 64)  256         ['add[0][0]']
#  zation)
#
#  stage1_unit2_relu1 (Activation  (None, 38, 38, 64)  0           ['stage1_unit2_bn1[0][0]']
#  )
#
#  zero_padding2d_4 (ZeroPadding2  (None, 40, 40, 64)  0           ['stage1_unit2_relu1[0][0]']
#  D)
#
#  stage1_unit2_conv1 (Conv2D)    (None, 38, 38, 64)   36864       ['zero_padding2d_4[0][0]']
#
#  stage1_unit2_bn2 (BatchNormali  (None, 38, 38, 64)  256         ['stage1_unit2_conv1[0][0]']
#  zation)
#
#  stage1_unit2_relu2 (Activation  (None, 38, 38, 64)  0           ['stage1_unit2_bn2[0][0]']
#  )
#
#  zero_padding2d_5 (ZeroPadding2  (None, 40, 40, 64)  0           ['stage1_unit2_relu2[0][0]']
#  D)
#
#  stage1_unit2_conv2 (Conv2D)    (None, 38, 38, 64)   36864       ['zero_padding2d_5[0][0]']
#
#  add_1 (Add)                    (None, 38, 38, 64)   0           ['stage1_unit2_conv2[0][0]',
#                                                                   'add[0][0]']
#
#  stage1_unit3_bn1 (BatchNormali  (None, 38, 38, 64)  256         ['add_1[0][0]']
#  zation)
#
#  stage1_unit3_relu1 (Activation  (None, 38, 38, 64)  0           ['stage1_unit3_bn1[0][0]']
#  )
#
#  zero_padding2d_6 (ZeroPadding2  (None, 40, 40, 64)  0           ['stage1_unit3_relu1[0][0]']
#  D)
#
#  stage1_unit3_conv1 (Conv2D)    (None, 38, 38, 64)   36864       ['zero_padding2d_6[0][0]']
#
#  stage1_unit3_bn2 (BatchNormali  (None, 38, 38, 64)  256         ['stage1_unit3_conv1[0][0]']
#  zation)
#
#  stage1_unit3_relu2 (Activation  (None, 38, 38, 64)  0           ['stage1_unit3_bn2[0][0]']
#  )
#
#  zero_padding2d_7 (ZeroPadding2  (None, 40, 40, 64)  0           ['stage1_unit3_relu2[0][0]']
#  D)
#
#  stage1_unit3_conv2 (Conv2D)    (None, 38, 38, 64)   36864       ['zero_padding2d_7[0][0]']
#
#  add_2 (Add)                    (None, 38, 38, 64)   0           ['stage1_unit3_conv2[0][0]',
#                                                                   'add_1[0][0]']
#
#  stage2_unit1_bn1 (BatchNormali  (None, 38, 38, 64)  256         ['add_2[0][0]']
#  zation)
#
#  stage2_unit1_relu1 (Activation  (None, 38, 38, 64)  0           ['stage2_unit1_bn1[0][0]']
#  )
#
#  zero_padding2d_8 (ZeroPadding2  (None, 40, 40, 64)  0           ['stage2_unit1_relu1[0][0]']
#  D)
#
#  stage2_unit1_conv1 (Conv2D)    (None, 19, 19, 128)  73728       ['zero_padding2d_8[0][0]']
#
#  stage2_unit1_bn2 (BatchNormali  (None, 19, 19, 128)  512        ['stage2_unit1_conv1[0][0]']
#  zation)
#
#  stage2_unit1_relu2 (Activation  (None, 19, 19, 128)  0          ['stage2_unit1_bn2[0][0]']
#  )
#
#  zero_padding2d_9 (ZeroPadding2  (None, 21, 21, 128)  0          ['stage2_unit1_relu2[0][0]']
#  D)
#
#  stage2_unit1_conv2 (Conv2D)    (None, 19, 19, 128)  147456      ['zero_padding2d_9[0][0]']
#
#  stage2_unit1_sc (Conv2D)       (None, 19, 19, 128)  8192        ['stage2_unit1_relu1[0][0]']
#
#  add_3 (Add)                    (None, 19, 19, 128)  0           ['stage2_unit1_conv2[0][0]',
#                                                                   'stage2_unit1_sc[0][0]']
#
#  stage2_unit2_bn1 (BatchNormali  (None, 19, 19, 128)  512        ['add_3[0][0]']
#  zation)
#
#  stage2_unit2_relu1 (Activation  (None, 19, 19, 128)  0          ['stage2_unit2_bn1[0][0]']
#  )
#
#  zero_padding2d_10 (ZeroPadding  (None, 21, 21, 128)  0          ['stage2_unit2_relu1[0][0]']
#  2D)
#
#  stage2_unit2_conv1 (Conv2D)    (None, 19, 19, 128)  147456      ['zero_padding2d_10[0][0]']
#
#  stage2_unit2_bn2 (BatchNormali  (None, 19, 19, 128)  512        ['stage2_unit2_conv1[0][0]']
#  zation)
#
#  stage2_unit2_relu2 (Activation  (None, 19, 19, 128)  0          ['stage2_unit2_bn2[0][0]']
#  )
#
#  zero_padding2d_11 (ZeroPadding  (None, 21, 21, 128)  0          ['stage2_unit2_relu2[0][0]']
#  2D)
#
#  stage2_unit2_conv2 (Conv2D)    (None, 19, 19, 128)  147456      ['zero_padding2d_11[0][0]']
#
#  add_4 (Add)                    (None, 19, 19, 128)  0           ['stage2_unit2_conv2[0][0]',
#                                                                   'add_3[0][0]']
#
#  stage2_unit3_bn1 (BatchNormali  (None, 19, 19, 128)  512        ['add_4[0][0]']
#  zation)
#
#  stage2_unit3_relu1 (Activation  (None, 19, 19, 128)  0          ['stage2_unit3_bn1[0][0]']
#  )
#
#  zero_padding2d_12 (ZeroPadding  (None, 21, 21, 128)  0          ['stage2_unit3_relu1[0][0]']
#  2D)
#
#  stage2_unit3_conv1 (Conv2D)    (None, 19, 19, 128)  147456      ['zero_padding2d_12[0][0]']
#
#  stage2_unit3_bn2 (BatchNormali  (None, 19, 19, 128)  512        ['stage2_unit3_conv1[0][0]']
#  zation)
#
#  stage2_unit3_relu2 (Activation  (None, 19, 19, 128)  0          ['stage2_unit3_bn2[0][0]']
#  )
#
#  zero_padding2d_13 (ZeroPadding  (None, 21, 21, 128)  0          ['stage2_unit3_relu2[0][0]']
#  2D)
#
#  stage2_unit3_conv2 (Conv2D)    (None, 19, 19, 128)  147456      ['zero_padding2d_13[0][0]']
#
#  add_5 (Add)                    (None, 19, 19, 128)  0           ['stage2_unit3_conv2[0][0]',
#                                                                   'add_4[0][0]']
#
#  stage2_unit4_bn1 (BatchNormali  (None, 19, 19, 128)  512        ['add_5[0][0]']
#  zation)
#
#  stage2_unit4_relu1 (Activation  (None, 19, 19, 128)  0          ['stage2_unit4_bn1[0][0]']
#  )
#
#  zero_padding2d_14 (ZeroPadding  (None, 21, 21, 128)  0          ['stage2_unit4_relu1[0][0]']
#  2D)
#
#  stage2_unit4_conv1 (Conv2D)    (None, 19, 19, 128)  147456      ['zero_padding2d_14[0][0]']
#
#  stage2_unit4_bn2 (BatchNormali  (None, 19, 19, 128)  512        ['stage2_unit4_conv1[0][0]']
#  zation)
#
#  stage2_unit4_relu2 (Activation  (None, 19, 19, 128)  0          ['stage2_unit4_bn2[0][0]']
#  )
#
#  zero_padding2d_15 (ZeroPadding  (None, 21, 21, 128)  0          ['stage2_unit4_relu2[0][0]']
#  2D)
#
#  stage2_unit4_conv2 (Conv2D)    (None, 19, 19, 128)  147456      ['zero_padding2d_15[0][0]']
#
#  add_6 (Add)                    (None, 19, 19, 128)  0           ['stage2_unit4_conv2[0][0]',
#                                                                   'add_5[0][0]']
#
#  stage3_unit1_bn1 (BatchNormali  (None, 19, 19, 128)  512        ['add_6[0][0]']
#  zation)
#
#  stage3_unit1_relu1 (Activation  (None, 19, 19, 128)  0          ['stage3_unit1_bn1[0][0]']
#  )
#
#  zero_padding2d_16 (ZeroPadding  (None, 21, 21, 128)  0          ['stage3_unit1_relu1[0][0]']
#  2D)
#
#  stage3_unit1_conv1 (Conv2D)    (None, 10, 10, 256)  294912      ['zero_padding2d_16[0][0]']
#
#  stage3_unit1_bn2 (BatchNormali  (None, 10, 10, 256)  1024       ['stage3_unit1_conv1[0][0]']
#  zation)
#
#  stage3_unit1_relu2 (Activation  (None, 10, 10, 256)  0          ['stage3_unit1_bn2[0][0]']
#  )
#
#  zero_padding2d_17 (ZeroPadding  (None, 12, 12, 256)  0          ['stage3_unit1_relu2[0][0]']
#  2D)
#
#  stage3_unit1_conv2 (Conv2D)    (None, 10, 10, 256)  589824      ['zero_padding2d_17[0][0]']
#
#  stage3_unit1_sc (Conv2D)       (None, 10, 10, 256)  32768       ['stage3_unit1_relu1[0][0]']
#
#  add_7 (Add)                    (None, 10, 10, 256)  0           ['stage3_unit1_conv2[0][0]',
#                                                                   'stage3_unit1_sc[0][0]']
#
#  stage3_unit2_bn1 (BatchNormali  (None, 10, 10, 256)  1024       ['add_7[0][0]']
#  zation)
#
#  stage3_unit2_relu1 (Activation  (None, 10, 10, 256)  0          ['stage3_unit2_bn1[0][0]']
#  )
#
#  zero_padding2d_18 (ZeroPadding  (None, 12, 12, 256)  0          ['stage3_unit2_relu1[0][0]']
#  2D)
#
#  stage3_unit2_conv1 (Conv2D)    (None, 10, 10, 256)  589824      ['zero_padding2d_18[0][0]']
#
#  stage3_unit2_bn2 (BatchNormali  (None, 10, 10, 256)  1024       ['stage3_unit2_conv1[0][0]']
#  zation)
#
#  stage3_unit2_relu2 (Activation  (None, 10, 10, 256)  0          ['stage3_unit2_bn2[0][0]']
#  )
#
#  zero_padding2d_19 (ZeroPadding  (None, 12, 12, 256)  0          ['stage3_unit2_relu2[0][0]']
#  2D)
#
#  stage3_unit2_conv2 (Conv2D)    (None, 10, 10, 256)  589824      ['zero_padding2d_19[0][0]']
#
#  add_8 (Add)                    (None, 10, 10, 256)  0           ['stage3_unit2_conv2[0][0]',
#                                                                   'add_7[0][0]']
#
#  stage3_unit3_bn1 (BatchNormali  (None, 10, 10, 256)  1024       ['add_8[0][0]']
#  zation)
#
#  stage3_unit3_relu1 (Activation  (None, 10, 10, 256)  0          ['stage3_unit3_bn1[0][0]']
#  )
#
#  zero_padding2d_20 (ZeroPadding  (None, 12, 12, 256)  0          ['stage3_unit3_relu1[0][0]']
#  2D)
#
#  stage3_unit3_conv1 (Conv2D)    (None, 10, 10, 256)  589824      ['zero_padding2d_20[0][0]']
#
#  stage3_unit3_bn2 (BatchNormali  (None, 10, 10, 256)  1024       ['stage3_unit3_conv1[0][0]']
#  zation)
#
#  stage3_unit3_relu2 (Activation  (None, 10, 10, 256)  0          ['stage3_unit3_bn2[0][0]']
#  )
#
#  zero_padding2d_21 (ZeroPadding  (None, 12, 12, 256)  0          ['stage3_unit3_relu2[0][0]']
#  2D)
#
#  stage3_unit3_conv2 (Conv2D)    (None, 10, 10, 256)  589824      ['zero_padding2d_21[0][0]']
#
#  add_9 (Add)                    (None, 10, 10, 256)  0           ['stage3_unit3_conv2[0][0]',
#                                                                   'add_8[0][0]']
#
#  stage3_unit4_bn1 (BatchNormali  (None, 10, 10, 256)  1024       ['add_9[0][0]']
#  zation)
#
#  stage3_unit4_relu1 (Activation  (None, 10, 10, 256)  0          ['stage3_unit4_bn1[0][0]']
#  )
#
#  zero_padding2d_22 (ZeroPadding  (None, 12, 12, 256)  0          ['stage3_unit4_relu1[0][0]']
#  2D)
#
#  stage3_unit4_conv1 (Conv2D)    (None, 10, 10, 256)  589824      ['zero_padding2d_22[0][0]']
#
#  stage3_unit4_bn2 (BatchNormali  (None, 10, 10, 256)  1024       ['stage3_unit4_conv1[0][0]']
#  zation)
#
#  stage3_unit4_relu2 (Activation  (None, 10, 10, 256)  0          ['stage3_unit4_bn2[0][0]']
#  )
#
#  zero_padding2d_23 (ZeroPadding  (None, 12, 12, 256)  0          ['stage3_unit4_relu2[0][0]']
#  2D)
#
#  stage3_unit4_conv2 (Conv2D)    (None, 10, 10, 256)  589824      ['zero_padding2d_23[0][0]']
#
#  add_10 (Add)                   (None, 10, 10, 256)  0           ['stage3_unit4_conv2[0][0]',
#                                                                   'add_9[0][0]']
#
#  stage3_unit5_bn1 (BatchNormali  (None, 10, 10, 256)  1024       ['add_10[0][0]']
#  zation)
#
#  stage3_unit5_relu1 (Activation  (None, 10, 10, 256)  0          ['stage3_unit5_bn1[0][0]']
#  )
#
#  zero_padding2d_24 (ZeroPadding  (None, 12, 12, 256)  0          ['stage3_unit5_relu1[0][0]']
#  2D)
#
#  stage3_unit5_conv1 (Conv2D)    (None, 10, 10, 256)  589824      ['zero_padding2d_24[0][0]']
#
#  stage3_unit5_bn2 (BatchNormali  (None, 10, 10, 256)  1024       ['stage3_unit5_conv1[0][0]']
#  zation)
#
#  stage3_unit5_relu2 (Activation  (None, 10, 10, 256)  0          ['stage3_unit5_bn2[0][0]']
#  )
#
#  zero_padding2d_25 (ZeroPadding  (None, 12, 12, 256)  0          ['stage3_unit5_relu2[0][0]']
#  2D)
#
#  stage3_unit5_conv2 (Conv2D)    (None, 10, 10, 256)  589824      ['zero_padding2d_25[0][0]']
#
#  add_11 (Add)                   (None, 10, 10, 256)  0           ['stage3_unit5_conv2[0][0]',
#                                                                   'add_10[0][0]']
#
#  stage3_unit6_bn1 (BatchNormali  (None, 10, 10, 256)  1024       ['add_11[0][0]']
#  zation)
#
#  stage3_unit6_relu1 (Activation  (None, 10, 10, 256)  0          ['stage3_unit6_bn1[0][0]']
#  )
#
#  zero_padding2d_26 (ZeroPadding  (None, 12, 12, 256)  0          ['stage3_unit6_relu1[0][0]']
#  2D)
#
#  stage3_unit6_conv1 (Conv2D)    (None, 10, 10, 256)  589824      ['zero_padding2d_26[0][0]']
#
#  stage3_unit6_bn2 (BatchNormali  (None, 10, 10, 256)  1024       ['stage3_unit6_conv1[0][0]']
#  zation)
#
#  stage3_unit6_relu2 (Activation  (None, 10, 10, 256)  0          ['stage3_unit6_bn2[0][0]']
#  )
#
#  zero_padding2d_27 (ZeroPadding  (None, 12, 12, 256)  0          ['stage3_unit6_relu2[0][0]']
#  2D)
#
#  stage3_unit6_conv2 (Conv2D)    (None, 10, 10, 256)  589824      ['zero_padding2d_27[0][0]']
#
#  add_12 (Add)                   (None, 10, 10, 256)  0           ['stage3_unit6_conv2[0][0]',
#                                                                   'add_11[0][0]']
#
#  stage4_unit1_bn1 (BatchNormali  (None, 10, 10, 256)  1024       ['add_12[0][0]']
#  zation)
#
#  stage4_unit1_relu1 (Activation  (None, 10, 10, 256)  0          ['stage4_unit1_bn1[0][0]']
#  )
#
#  zero_padding2d_28 (ZeroPadding  (None, 12, 12, 256)  0          ['stage4_unit1_relu1[0][0]']
#  2D)
#
#  stage4_unit1_conv1 (Conv2D)    (None, 5, 5, 512)    1179648     ['zero_padding2d_28[0][0]']
#
#  stage4_unit1_bn2 (BatchNormali  (None, 5, 5, 512)   2048        ['stage4_unit1_conv1[0][0]']
#  zation)
#
#  stage4_unit1_relu2 (Activation  (None, 5, 5, 512)   0           ['stage4_unit1_bn2[0][0]']
#  )
#
#  zero_padding2d_29 (ZeroPadding  (None, 7, 7, 512)   0           ['stage4_unit1_relu2[0][0]']
#  2D)
#
#  stage4_unit1_conv2 (Conv2D)    (None, 5, 5, 512)    2359296     ['zero_padding2d_29[0][0]']
#
#  stage4_unit1_sc (Conv2D)       (None, 5, 5, 512)    131072      ['stage4_unit1_relu1[0][0]']
#
#  add_13 (Add)                   (None, 5, 5, 512)    0           ['stage4_unit1_conv2[0][0]',
#                                                                   'stage4_unit1_sc[0][0]']
#
#  stage4_unit2_bn1 (BatchNormali  (None, 5, 5, 512)   2048        ['add_13[0][0]']
#  zation)
#
#  stage4_unit2_relu1 (Activation  (None, 5, 5, 512)   0           ['stage4_unit2_bn1[0][0]']
#  )
#
#  zero_padding2d_30 (ZeroPadding  (None, 7, 7, 512)   0           ['stage4_unit2_relu1[0][0]']
#  2D)
#
#  stage4_unit2_conv1 (Conv2D)    (None, 5, 5, 512)    2359296     ['zero_padding2d_30[0][0]']
#
#  stage4_unit2_bn2 (BatchNormali  (None, 5, 5, 512)   2048        ['stage4_unit2_conv1[0][0]']
#  zation)
#
#  stage4_unit2_relu2 (Activation  (None, 5, 5, 512)   0           ['stage4_unit2_bn2[0][0]']
#  )
#
#  zero_padding2d_31 (ZeroPadding  (None, 7, 7, 512)   0           ['stage4_unit2_relu2[0][0]']
#  2D)
#
#  stage4_unit2_conv2 (Conv2D)    (None, 5, 5, 512)    2359296     ['zero_padding2d_31[0][0]']
#
#  add_14 (Add)                   (None, 5, 5, 512)    0           ['stage4_unit2_conv2[0][0]',
#                                                                   'add_13[0][0]']
#
#  stage4_unit3_bn1 (BatchNormali  (None, 5, 5, 512)   2048        ['add_14[0][0]']
#  zation)
#
#  stage4_unit3_relu1 (Activation  (None, 5, 5, 512)   0           ['stage4_unit3_bn1[0][0]']
#  )
#
#  zero_padding2d_32 (ZeroPadding  (None, 7, 7, 512)   0           ['stage4_unit3_relu1[0][0]']
#  2D)
#
#  stage4_unit3_conv1 (Conv2D)    (None, 5, 5, 512)    2359296     ['zero_padding2d_32[0][0]']
#
#  stage4_unit3_bn2 (BatchNormali  (None, 5, 5, 512)   2048        ['stage4_unit3_conv1[0][0]']
#  zation)
#
#  stage4_unit3_relu2 (Activation  (None, 5, 5, 512)   0           ['stage4_unit3_bn2[0][0]']
#  )
#
#  zero_padding2d_33 (ZeroPadding  (None, 7, 7, 512)   0           ['stage4_unit3_relu2[0][0]']
#  2D)
#
#  stage4_unit3_conv2 (Conv2D)    (None, 5, 5, 512)    2359296     ['zero_padding2d_33[0][0]']
#
#  add_15 (Add)                   (None, 5, 5, 512)    0           ['stage4_unit3_conv2[0][0]',
#                                                                   'add_14[0][0]']
#
#  bn1 (BatchNormalization)       (None, 5, 5, 512)    2048        ['add_15[0][0]']
#
#  relu1 (Activation)             (None, 5, 5, 512)    0           ['bn1[0][0]']
#
# ==================================================================================================
# Total params: 21,302,473
# Trainable params: 21,287,107
# Non-trainable params: 15,366
# __________________________________________________________________________________________________

# %%
# ResNet34, preprocess_input = Classifiers.get('resnet34')
# conv_base = ResNet34(input_shape = size_3d, include_top = False) # by default, it brings in the imagenet weights

# conv_base.summary()

# %% [markdown]
# After running through the convolution layers, the ouput is 10 by 10 by 512.

# %% [markdown]
# ### Create our data generators and define batch size

# %%
batch = 20
epoch_number = 30

# %%
epoch_number = 30 

training_length = len(train)
validation_length = len(val)
test_length = len(test) 

print(training_length)
print(validation_length)
print(test_length)

# create steps for train, val, and test for later
def steps(length, batch): 
  if length % batch == 0:
    return (int(length / batch))
  else:
    return (int((length / batch) + 1))

training_steps = steps(training_length, batch)
validation_steps = steps(validation_length, batch)
test_steps = steps(test_length, batch)
print(training_steps)
print(validation_steps)
print(test_steps)
# Out:
# 103364
# 44299
# 16407
# 5169
# 2215
# 821

# %%
train_datagen = ImageDataGenerator(
    rescale = 1./255, 
)

val_test_datagen = ImageDataGenerator(
    rescale = 1./255, 
)

train_generator = train_datagen.flow_from_dataframe(
    train,
    directory = None, # don't need to specify directory bc our train df has absolute paths to photos
    x_col = "Path", # specify column with path information to photos
    y_col = "Race", # specify where to find classes
    class_mode = "categorical", # specify what kind of classes, for multi use 'categorical'
    target_size = size, # need to put in input size 
    shuffle = True,
    seed = 261,
    batch_size = batch)

val_generator = val_test_datagen.flow_from_dataframe(
    val, 
    directory = None, # don't need to specify directory bc our train df has absolute paths to photos
    x_col = "Path", # specify column with path information to photos
    y_col = "Race", # specify where to find classes
    class_mode = "categorical", # specify what kind of classes, for multi use 'categorical'
    target_size = size, # need to put in input size 
    shuffle = True,
    seed = 261,
    batch_size = batch)

test_generator = val_test_datagen.flow_from_dataframe(
    test, 
    directory = None, # don't need to specify directory bc our train df has absolute paths to photos
    x_col = "Path", # specify column with path information to photos
    y_col = "Race", # specify where to find classes
    class_mode = "categorical", # specify what kind of classes, for multi use 'categorical'
    target_size = size, # need to put in input size 
    shuffle = True,
    seed = 261,
    batch_size = batch)
# Out:
# Found 103364 validated image filenames belonging to 4 classes.
# Found 44299 validated image filenames belonging to 4 classes.
# Found 16407 validated image filenames belonging to 4 classes.

# %%
#np.savetxt("train_features.csv", train_features, delimiter=",")
#np.savetxt("train_labels.csv", train_labels, delimiter=",")

#np.savetxt("validation_features.csv", validation_features, delimiter=",")
#np.savetxt("validation_labels.csv", validation_labels, delimiter=",")

#np.savetxt("test_features.csv", test_features, delimiter=",")
#np.savetxt("test_labels.csv", test_labels, delimiter=",")

# %%
model_final = tf.keras.models.Sequential([
    model,
    keras.layers.Flatten(),
    keras.layers.Dense(number_classes, activation='softmax')]
)

#x = model.output
#predictions = keras.layers.Dense(number_classes, activation= 'softmax')(x)
#model = tf.keras.Model(inputs = model.input, outputs = predictions)

opt = tf.keras.optimizers.Adam(learning_rate = 0.001)

model_final.compile(optimizer = opt,
              loss = 'categorical_crossentropy',
              metrics=['accuracy'])

history1 = model_final.fit(train_generator,
                    epochs = epoch_number,
                    batch_size = batch,
                    validation_data = val_generator,
                    steps_per_epoch = training_steps,
                    validation_steps = validation_steps)
# Out:
# Epoch 1/30
# 5169/5169 [==============================] - 360s 67ms/step - loss: 0.7824 - accuracy: 0.7595 - val_loss: 0.8112 - val_accuracy: 0.7645
# Epoch 2/30
# 5169/5169 [==============================] - 293s 57ms/step - loss: 0.7086 - accuracy: 0.7639 - val_loss: 0.7039 - val_accuracy: 0.7649
# Epoch 3/30
# 5169/5169 [==============================] - 287s 56ms/step - loss: 0.6999 - accuracy: 0.7641 - val_loss: 0.7293 - val_accuracy: 0.7600
# Epoch 4/30
# 5169/5169 [==============================] - 290s 56ms/step - loss: 0.6866 - accuracy: 0.7650 - val_loss: 0.6799 - val_accuracy: 0.7660
# Epoch 5/30
# 5169/5169 [==============================] - 290s 56ms/step - loss: 0.6728 - accuracy: 0.7660 - val_loss: 0.7322 - val_accuracy: 0.7536
# Epoch 6/30
# 5169/5169 [==============================] - 290s 56ms/step - loss: 0.6620 - accuracy: 0.7688 - val_loss: 0.6926 - val_accuracy: 0.7688
# Epoch 7/30
# 5169/5169 [==============================] - 292s 57ms/step - loss: 0.6496 - accuracy: 0.7713 - val_loss: 0.6851 - val_accuracy: 0.7699
# Epoch 8/30
# 5169/5169 [==============================] - 291s 56ms/step - loss: 0.6346 - accuracy: 0.7750 - val_loss: 0.7932 - val_accuracy: 0.7657
# Epoch 9/30
# 5169/5169 [==============================] - 288s 56ms/step - loss: 0.6184 - accuracy: 0.7791 - val_loss: 0.6437 - val_accuracy: 0.7761
# Epoch 10/30
# 5169/5169 [==============================] - 281s 54ms/step - loss: 0.6011 - accuracy: 0.7848 - val_loss: 0.6992 - val_accuracy: 0.7599
# Epoch 11/30
# 5169/5169 [==============================] - 279s 54ms/step - loss: 0.5891 - accuracy: 0.7887 - val_loss: 0.6373 - val_accuracy: 0.7834
# Epoch 12/30
# 5169/5169 [==============================] - 279s 54ms/step - loss: 0.5431 - accuracy: 0.8038 - val_loss: 0.6195 - val_accuracy: 0.7820
# Epoch 13/30
# 5169/5169 [==============================] - 281s 54ms/step - loss: 0.4911 - accuracy: 0.8230 - val_loss: 0.6986 - val_accuracy: 0.7414
# Epoch 14/30
# 5169/5169 [==============================] - 281s 54ms/step - loss: 0.4180 - accuracy: 0.8480 - val_loss: 0.6717 - val_accuracy: 0.7783
# Epoch 15/30
# 5169/5169 [==============================] - 278s 54ms/step - loss: 0.3109 - accuracy: 0.8860 - val_loss: 0.8155 - val_accuracy: 0.7812
# Epoch 16/30
# 5169/5169 [==============================] - 278s 54ms/step - loss: 0.2019 - accuracy: 0.9258 - val_loss: 0.9698 - val_accuracy: 0.7302
# Epoch 17/30
# 5169/5169 [==============================] - 280s 54ms/step - loss: 0.1358 - accuracy: 0.9502 - val_loss: 1.1824 - val_accuracy: 0.7377
# Epoch 18/30
# 5169/5169 [==============================] - 282s 55ms/step - loss: 0.1016 - accuracy: 0.9625 - val_loss: 1.2316 - val_accuracy: 0.7165
# Epoch 19/30
# 5169/5169 [==============================] - 283s 55ms/step - loss: 0.0867 - accuracy: 0.9684 - val_loss: 1.4139 - val_accuracy: 0.7636
# Epoch 20/30
# 5169/5169 [==============================] - 279s 54ms/step - loss: 0.0753 - accuracy: 0.9727 - val_loss: 1.4794 - val_accuracy: 0.7693
# Epoch 21/30
# 5169/5169 [==============================] - 284s 55ms/step - loss: 0.0682 - accuracy: 0.9756 - val_loss: 1.6876 - val_accuracy: 0.7769
# Epoch 22/30
# 5169/5169 [==============================] - 274s 53ms/step - loss: 0.0607 - accuracy: 0.9783 - val_loss: 1.7361 - val_accuracy: 0.7739
# Epoch 23/30
# 5169/5169 [==============================] - 279s 54ms/step - loss: 0.0568 - accuracy: 0.9798 - val_loss: 1.5202 - val_accuracy: 0.7151
# Epoch 24/30
# 5169/5169 [==============================] - 279s 54ms/step - loss: 0.0520 - accuracy: 0.9816 - val_loss: 1.5072 - val_accuracy: 0.7363
# Epoch 25/30
# 5169/5169 [==============================] - 280s 54ms/step - loss: 0.0508 - accuracy: 0.9825 - val_loss: 1.5675 - val_accuracy: 0.7516
# Epoch 26/30
# 5169/5169 [==============================] - 278s 54ms/step - loss: 0.0466 - accuracy: 0.9834 - val_loss: 1.5645 - val_accuracy: 0.7246
# Epoch 27/30
# 5169/5169 [==============================] - 279s 54ms/step - loss: 0.0432 - accuracy: 0.9845 - val_loss: 1.5861 - val_accuracy: 0.7393
# Epoch 28/30
# 5169/5169 [==============================] - 278s 54ms/step - loss: 0.0428 - accuracy: 0.9852 - val_loss: 1.5962 - val_accuracy: 0.7569
# Epoch 29/30
# 5169/5169 [==============================] - 277s 54ms/step - loss: 0.0392 - accuracy: 0.9865 - val_loss: 1.6900 - val_accuracy: 0.7606
# Epoch 30/30
# 5169/5169 [==============================] - 276s 53ms/step - loss: 0.0383 - accuracy: 0.9868 - val_loss: 1.7023 - val_accuracy: 0.7665

# %%
#K.clear_session()
#del model1

# %%
#!nvidia-smi

# %%
#!nvidia-smi -L

# %%
# serialize model to JSON
model_json = model_final.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model_final.save_weights("model.h5")
print("Saved model to disk")

from google.colab import files
files.download("model.json")
files.download("model.h5")
# Out:
# Saved model to disk

# %% [markdown]
# # Visualize Results

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()

train_acc = history1.history['accuracy']
train_loss = history1.history['loss']
val_acc = history1.history['val_accuracy']
val_loss = history1.history['val_loss']

epochs = range(1, len(train_acc) + 1)

plt.plot(epochs, train_loss, label = "Training Loss")
plt.plot(epochs, val_loss, label = "Validation Loss")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title("Training vs. Validation Loss")
plt.legend()

# %%
scores = model_final.evaluate(test_generator)
print("The test set accuracy was: ", scores[1])
# Out:
# 821/821 [==============================] - 35s 42ms/step - loss: 1.6804 - accuracy: 0.7692
# The test set accuracy was:  0.769183874130249

# %%
features = np.zeros(shape=(test_length, number_classes)) # from summary above
labels = np.zeros(shape=(test_length, number_classes)) # 4 = number of classes
i = 0

for inputs_batch, labels_batch in tqdm(test_generator):
        features_batch = model_final.predict(inputs_batch)
        features[i * batch: (i + 1) * batch] = features_batch
        labels[i * batch : (i + 1) * batch] = labels_batch
        i += 1
        if i  * batch >= test_length:
            # Note that since generators yield data indefinitely in a loop,
            # we must `break` after every image has been seen once.
            break
# Out:
#   0%|          | 0/821 [00:00<?, ?it/s]

# %% [markdown]
# ### Confusion Matrix

# %%
# predictions = multilabel_predict_test = model_final.predict(test_generator, 
#                                                        batch_size = batch, 
#                                                        verbose=1, 
#                                                        steps = test_steps)

# %%
#predictions

# %%
y_hat = np.argmax(features, axis=1)
y_hat
# Out:
# array([3, 3, 1, ..., 3, 3, 3])

# %%
y_actual = np.argmax(labels, axis=1)
y_actual
# Out:
# array([3, 3, 3, ..., 3, 1, 1])

# %%
# extract the patient id number from the Path variable (index 2 in the path)
# path_split_test =  test_labels.Path.str.split("/", expand = True)
# test_labels['ID'] = path_split_test[2]

# # merge the race labels with the main label dataset
# test_labels = test_labels.merge(race_labels, on = 'ID')

# %%
# black_african_american_index_test = (test_labels.PRIMARY_RACE.str.contains('Black', na = False))
# test_labels.loc[black_african_american_index, 'Race'] = 'Black/African American'

# white_index_test = (test_labels.PRIMARY_RACE.str.contains('White', na = False))
# test_labels.loc[white_index, 'Race'] = 'White'

# asian_index_test = (test_labels.PRIMARY_RACE.str.contains('Asian', na = False))
# test_labels.loc[asian_index, 'Race'] = 'Asian'

# native_american_index_test = (test_labels.PRIMARY_RACE.str.contains('Native|Indian', na = False, regex = True))
# test_labels.loc[native_american_index, 'Race'] = 'Native American'

# %%
# test_labels.Race.value_counts(dropna = False)
# test_labels = test_labels.dropna(subset=['Race'])

# %%
# test_labels.Race

# %%
# test_labels.Race.iloc[np.where(test_labels.Race == 'White')] = 3

# %%
# test_labels.Race.iloc[np.where(test_labels.Race == 'Black/African American')] = 1

# %%
# test_labels.Race.iloc[np.where(test_labels.Race == 'Asian')] = 0

# %%
# test_labels.Race.iloc[np.where(test_labels.Race == 'Native American')] = 2

# %%
# test_labels.Race.value_counts()

# %%
# y_actual = np.array(test_labels.Race)

# %%
# y_actual = np.argmax(test_labels.Race, axis = 1)
# y_actual

# %%
def plot_confusion_matrix(y_label, y_pred, title='Confusion matrix'):
    ### TODO 1

    if type(y_pred) == 'numpy.ndarray':
      y_pred_vector = y_pred.tolist()
    else:
      y_pred_vector = y_pred

    if type(y_label) == 'numpy.ndarray':
      y_label_vector = y_label.tolist()
    else:
      y_label_vector = y_label

    classes = np.unique(y_label_vector)
    num_classes = len(np.unique(y_label_vector))
    matrix = np.zeros((num_classes, num_classes))
    for truth in range(len(classes)):
      for prediction in range(len(classes)):
        matrix[truth, prediction] = np.sum((y_label_vector == classes[truth]) & (y_pred_vector == classes[prediction]))

    matrix_percent = matrix/ (matrix.sum(axis  = 1)[:,None])



    labels = (np.asarray(["{0} \n {1:.2%}".format(number, percent) for number, percent in zip(matrix.flatten(), matrix_percent.flatten())])).reshape(num_classes, num_classes)
    ax1 = sns.heatmap(matrix_percent, annot=labels, cmap='Blues', fmt = '')
    ax1.set_title(title)
    ax1.set_xlabel('Predicted Class')
    ax1.set_ylabel('Actual Class')
    plt.show()


  
plot_confusion_matrix(y_actual, y_hat)

# %% [markdown]
# 0 = Asian
#
# 1 = Black/African American
#
# 2 = Native American
#
# 3 = White

# %%
print(classification_report(y_actual, y_hat, target_names = ['Asian', 'Black/African American', 'Native American', 'White']))
# Out:
#                         precision    recall  f1-score   support
#
#                  Asian       0.52      0.36      0.42      2327
# Black/African American       0.36      0.29      0.32      1196
#        Native American       0.15      0.04      0.06       335
#                  White       0.83      0.91      0.87     12549
#
#               accuracy                           0.77     16407
#              macro avg       0.46      0.40      0.42     16407
#           weighted avg       0.74      0.77      0.75     16407

# %% [markdown]
# ### PR - AUC

# %%
y_actual_flat = y_actual.flatten()
y_hat_flat = y_hat.flatten()

# Assign class numbers
Asian = 0
Black_African_American = 1
Native_American = 2
White = 3

# %%
precision = dict()
recall = dict()
average_precision = dict()
for i in range(number_classes):
    precision[i], recall[i], _ = precision_recall_curve(labels[:, i], features[:, i])
    average_precision[i] = average_precision_score(labels[:, i], features[:, i])

# get average pr score over all classes
precision["micro"], recall["micro"], _ = precision_recall_curve(
    labels.ravel(), features.ravel()
)
average_precision["micro"] = average_precision_score(labels, features, average="micro")

# %%
display = PrecisionRecallDisplay(
    recall=recall["micro"],
    precision=precision["micro"],
    average_precision=average_precision["micro"],
)
display.plot()
_ = display.ax_.set_title("Micro-averaged over all classes - Model from Scratch")

# %%
colors = cycle(["navy", "turquoise", "darkorange", "cornflowerblue"])
classes = ['Asian', 'Black/African American', 'Native American', 'White']
_, ax = plt.subplots(figsize=(7, 8))

f_scores = np.linspace(0.2, 0.8, num=4)
lines, labels = [], []
for f_score in f_scores:
    x = np.linspace(0.01, 1)
    y = f_score * x / (2 * x - f_score)
    (l,) = plt.plot(x[y >= 0], y[y >= 0], color="gray", alpha=0.2)
    plt.annotate("f1={0:0.1f}".format(f_score), xy=(0.9, y[45] + 0.02))

display = PrecisionRecallDisplay(
    recall=recall["micro"],
    precision=precision["micro"],
    average_precision=average_precision["micro"],
)
display.plot(ax=ax, name="Micro-average precision-recall", color="gold")

for i, color in zip(range(number_classes), colors):
    display = PrecisionRecallDisplay(
        recall=recall[i],
        precision=precision[i],
        average_precision=average_precision[i],
    )
    display.plot(ax=ax, name=f"Precision-recall: {classes[i]}", color=color)

# add the legend for the iso-f1 curves
handles, labels = display.ax_.get_legend_handles_labels()
handles.extend([l])
labels.extend(["iso-f1 curves"])
# set the legend and the axes
ax.set_xlim([0.0, 1.0])
ax.set_ylim([0.0, 1.05])
ax.legend(handles=handles, labels=labels, loc="best")
ax.set_title("Extension of Precision-Recall curve to multi-class - Model from Scratch")

plt.show()
